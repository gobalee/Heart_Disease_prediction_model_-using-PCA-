# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
y = df['HeartDisease']

# %%
X = df
X.drop(columns = 'HeartDisease', inplace = True)

# %%
X.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope
# 0              N      0.0       Up
# 1              N      1.0     Flat
# 2              N      0.0       Up
# 3              Y      1.5     Flat
# 4              N      0.0       Up

# %%
# to get dummies

# %%
X_dum = pd.get_dummies(X, drop_first = True)

# %%
X_dum
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 0     40        140          289          0    172      0.0      1
# 1     49        160          180          0    156      1.0      0
# 2     37        130          283          0     98      0.0      1
# 3     48        138          214          0    108      1.5      0
# 4     54        150          195          0    122      0.0      1
# ..   ...        ...          ...        ...    ...      ...    ...
# 913   45        110          264          0    132      1.2      1
# 914   68        144          193          1    141      3.4      1
# 915   57        130          131          0    115      1.2      1
# 916   57        130          236          0    174      0.0      0
# 917   38        138          175          0    173      0.0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0                    1                  0                 0
# ...

# %%
scaler = preprocessing.StandardScaler()

# %%
X_sc = scaler.fit_transform(X_dum)
X_sc
# Out:
# array([[-1.4331398 ,  0.41090889,  0.82507026, ..., -0.8235563 ,
#         -1.00218103,  1.15067399],
#        [-0.47848359,  1.49175234, -0.17196105, ..., -0.8235563 ,
#          0.99782372, -0.86905588],
#        [-1.75135854, -0.12951283,  0.7701878 , ..., -0.8235563 ,
#         -1.00218103,  1.15067399],
#        ...,
#        [ 0.37009972, -0.12951283, -0.62016778, ...,  1.21424608,
#          0.99782372, -0.86905588],
#        [ 0.37009972, -0.12951283,  0.34027522, ..., -0.8235563 ,
#          0.99782372, -0.86905588],
#        [-1.64528563,  0.30282455, -0.21769643, ..., -0.8235563 ,
#         -1.00218103,  1.15067399]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dum, y)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model1 = RandomForestClassifier()

# %%
model1.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model1.score(X_test, y_test)
# Out:
# 0.8956521739130435

# %% [markdown]
# # Using PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(0.98
          )

# %%
X_pca = pca.fit_transform(X_dum)

# %%
pd.DataFrame(X_pca)
# Out:
#              0          1          2
# 0    92.311315 -29.445651 -12.023584
# 1   -17.143665 -13.736029 -31.481309
# 2    81.906717  38.223511  16.066019
# 3    13.654574  28.745909   2.732691
# 4    -4.348523  18.094899 -13.440933
# ..         ...        ...        ...
# 913  64.490453   1.444165  25.554464
# 914  -5.472467   0.830304 -13.808851
# 915 -69.003773  17.334602   5.339174
# 916  39.206761 -33.591950  -6.126429
# 917 -21.437564 -37.216610 -13.582028
#
# [918 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y)

# %%
model2 = RandomForestClassifier()

# %%
model2.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model2.score(X_test, y_test)
# Out:
# 0.7043478260869566

# %% [markdown]
# > The model with reduced features gets an **acccuracy score of `70.4`%**
